# %% [markdown]
# ## Transformar a imagem em escala de cinza

# %%
from PIL import Image

# %%
img = Image.open('gray-cat.jpg').convert('LA')

# %% [markdown]
# ![cat_ingray.png](attachment:cat_ingray.png)

# %% [markdown]
# ![gray-cat.jpg](attachment:gray-cat.jpg)

# %% [markdown]
# ## Acessando os Pixels da Imagem

# %%
import cv2
import numpy as np

# %%
imagem = cv2.imread('cat_ingray.png', cv2.IMREAD_COLOR)

# %%
cv2.imshow('Original', imagem)
cv2.waitKey(0)
# Out:
# -1

# %%
altura, largura, bytesPorPixel = np.shape(imagem)

# %%
#for py in range(0, altura):
#    for px in range(0, largura):
#        print(imagem[py][px])

# %% [markdown]
# ## Redimensionar a Imagem

# %%
img = cv2.imread('gray-cat.jpg', cv2.IMREAD_UNCHANGED)
cv2.imshow('Imagem Original', img)
cv2.waitKey(0)
# Out:
# -1

# %%
print('Dimensões originais: ', img.shape) ## 511x768, com os 3 canais RGB
# Out:
# Dimensões originais:  (511, 768, 3)

# %%
scale_percent = 10 #proporção em relação à imagem original
width = int(img.shape[1] * scale_percent/100)
height = int(img.shape[0] * scale_percent/100)
dim = (width, height)

resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
print('Dimensões alteradas: ', resized.shape)
# Out:
# Dimensões alteradas:  (51, 76, 3)

# %%
cv2.imshow('Imagem Redimensionada', resized)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ### Reduzindo a imagem

# %%
#seleciona uma em cada duas colunas e uma a cada 2 linhas
m, n = 2, 2
img_red = img[::n, ::m]

cv2.imshow('Reduzida', img_red)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ### Aumentanndo a imagem

# %%
#Os pixels da imagem atual serão duplicados no eixo x e y.
m = 3
img_aum = np.repeat(img_red, m, axis=0) # x
img_aum = np.repeat(img_aum, m, axis=1) # y
cv2.imshow('Aumentada', img_aum)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# ### Quantização

# %%
# 255 / 31 = 8,22...
# Assim, teremos uma imagem com 8 tons de cinza.
imagem_cinza = cv2.imread('cat_ingray.png')

r = 15
imgQuant = np.uint8(imagem_cinza / r) * r
cv2.imshow('Quantizada', imgQuant)
cv2.waitKey(0)
# Out:
# -1
